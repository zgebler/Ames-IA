# %% [markdown]
# # Modeling Housing Prices on Ames IA Dataset

# %% [markdown]
# ### Import Libraries and set Tensorflows environment

# %%
import os
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "99"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib


import itertools
from sklearn.linear_model import LinearRegression, LassoLarsCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %matplotlib inline

# %%
# Import Data
x = pd.read_csv("data/features.csv", index_col = 0)
y = pd.read_csv("data/target.csv", index_col = 0)

# %% [markdown]
# ### Train-Test-Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape
# Out:
# (970, 17)

# %% [markdown]
# ### Instantiate and fit Linear Model

# %%
# Fit Linear Regression
lr = LinearRegression()
lr.fit(X_train, np.log(y_train))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test)

# %%
def error(actual, predicted):
    actual = np.log(actual)
    predicted = np.log(predicted)
    return np.sqrt(np.sum(np.square(actual-predicted))/len(actual))

# %%
error(y_test, np.exp(y_pred))
# Out:
# SalePrice    0.148273
# dtype: float64

# %% [markdown]
# ### Visualize Model Performance

# %%
fig, ax = plt.subplots(figsize=(50, 40))

plt.style.use('ggplot')
plt.plot(np.exp(y_pred), y_test, 'ro')
plt.xlabel('Predictions', fontsize = 30)
plt.ylabel('Reality', fontsize = 30)
plt.title('Predictions x Reality: LinearRegression', fontsize = 30)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.show()

# %%
# Interpretation of Features
features_df = pd.DataFrame(lr.coef_.T, X_train.columns, columns=['Importance'])



features_df['abs'] = np.abs(features_df['Importance'])
features_df.sort_values('abs', ascending = False)
# Out:
#                  Importance       abs
# GrLivArea          0.402479  0.402479
# TotalBsmtSF       -0.127412  0.127412
# KitchenQual_E      0.071156  0.071156
# GarageCars         0.040808  0.040808
# OverallQual        0.033867  0.033867
# BsmtQual_E         0.029727  0.029727
# FullBath          -0.029067  0.029067
# GarageFinish_E     0.026181  0.026181
# TotalBsmtSF2       0.020928  0.020928
# Neighborhood_E     0.013468  0.013468
# GarageType_E       0.013065  0.013065
# ExterQual_E        0.007879  0.007879
# Foundation_E      -0.004077  0.004077
# OverallQual2       0.001986  0.001986
# GarageArea        -0.000463  0.000463
# YearBuilt          0.000341  0.000341
# Neighborhood_E2   -0.000116  0.000116

# %% [markdown]
# ### Use Tensoflows API to run DNNRegressor

# %%
# Import Data
x = pd.read_csv("data/features.csv", index_col = 0)
y = pd.read_csv("data/target.csv", index_col = 0)

# %%
# Scale our data for Tensoflows
scaler = MinMaxScaler()
x = pd.DataFrame(scaler.fit_transform(x),
                  columns = x.columns, index = x.index)
scaler_y = MinMaxScaler()
y = pd.DataFrame(scaler_y.fit_transform(y),
                 columns= y.columns, index = y.index)

# %%
x.head()
# Out:
#    OverallQual  GrLivArea  GarageCars  YearBuilt  GarageArea  FullBath  \
# 0     0.666667   0.686018        0.50   0.949275    0.871552  0.666667
# 1     0.555556   0.558302        0.50   0.753623    0.847414  0.666667
# 2     0.666667   0.704301        0.50   0.934783    0.885882  0.666667
# 3     0.666667   0.687736        0.75   0.311594    0.893388  0.333333
# 4     0.777778   0.791579        0.75   0.927536    0.929819  0.666667
#
#    TotalBsmtSF  ExterQual_E  BsmtQual_E  KitchenQual_E  Neighborhood_E  \
# 0     0.836537     0.666667        0.75       0.666667        0.666667
# 1     0.884574     0.333333        0.75       0.333333        0.833333
# 2     0.845458     0.666667        0.75       0.666667        0.666667
# 3     0.821168     0.333333        0.50       0.666667        0.708333
# 4     0.872532     0.666667        0.75       0.666667        1.000000
#
#    GarageFinish_E  GarageType_E  Foundation_E  OverallQual2  TotalBsmtSF2  \
# 0        0.666667      0.833333           1.0      0.484848      0.699794
# 1        0.666667      0.833333           0.4      0.353535      0.782471
# 2        0.666667      0.833333           1.0      0.484848      0.714799
# 3        0.333333      0.333333           0.2      0.484848      0.674317
# 4        0.666667      0.833333           1.0      0.636364      0.761313
#
#    Neighborhood_E2
# 0         0.461538
# 1         0.705128
# 2         0.461538
# 3         0.517628
# 4         1.000000

# %%
feature_names = x.columns

# %%
# List of features
engineered_features = []

for continuous_feature in feature_names:
    engineered_features.append(
        tf.feature_column.numeric_column(continuous_feature))

# Train and Test 
x_train, x_test, y_train, y_test = train_test_split(x ,
                                                    y, test_size=0.33, random_state=42)
y_train = pd.DataFrame(y_train, columns = ['SalePrice'])
y_test  = pd.DataFrame(y_test, columns = ['SalePrice'])

training_set = pd.DataFrame(x_train, columns = feature_names).merge(y_train, left_index = True, right_index = True)
testing_set  = pd.DataFrame(x_test, columns = feature_names).merge(y_test, left_index = True, right_index = True)

# %% [markdown]
# ### Define our input functions and model

# %%
def input_fn_new(data_set, training = True):
    continuous_cols = {k: tf.constant(data_set[k].values) for k in feature_names}
    
    
    feature_cols = dict(list(continuous_cols.items()))
    
    if training == True:
        # Converts the label column into a constant Tensor.
        label = tf.constant(data_set['SalePrice'].values)

        # Returns the feature columns and the label.
        return feature_cols, label
    
    return feature_cols

# Model
regressor = tf.estimator.DNNRegressor(feature_columns = engineered_features, 
                                          activation_fn = tf.nn.relu, hidden_units=[200, 100, 50, 25, 12])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zgebl\\AppData\\Local\\Temp\\tmpubngb3se', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# Deep Neural Network Regressor on our training data

losses = []

for iteration in range(5):

    regressor.train(input_fn = lambda: input_fn_new(training_set) , steps=10)
    ev = regressor.evaluate(input_fn=lambda: input_fn_new(testing_set, training = True), steps=1)
    losses.append(ev['loss'])
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2570
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2570 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:loss = 0.007973406, step = 2570
# INFO:tensorflow:Saving checkpoints for 2580 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.007962904.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:59:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2580
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.25135s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:59:01
# INFO:tensorflow:Saving dict for global step 2580: average_loss = 0.008499797, global_step = 2580, label/mean = 0.31787005, loss = 0.008499797, prediction/mean = 0.32108173
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2580: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2580
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2580
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2580 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:loss = 0.0079617435, step = 2580
# INFO:tensorflow:Saving checkpoints for 2590 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.007951312.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:59:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2590
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.26693s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:59:03
# INFO:tensorflow:Saving dict for global step 2590: average_loss = 0.008488471, global_step = 2590, label/mean = 0.31787005, loss = 0.008488471, prediction/mean = 0.32105908
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2590: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2590
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2590
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2590 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:loss = 0.007950159, step = 2590
# INFO:tensorflow:Saving checkpoints for 2600 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0079398025.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:59:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.26980s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:59:05
# INFO:tensorflow:Saving dict for global step 2600: average_loss = 0.0084772445, global_step = 2600, label/mean = 0.31787005, loss = 0.0084772445, prediction/mean = 0.32104567
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2600: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2600
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2600 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:loss = 0.007938651, step = 2600
# INFO:tensorflow:Saving checkpoints for 2610 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.007928325.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:59:07Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2610
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.22046s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:59:07
# INFO:tensorflow:Saving dict for global step 2610: average_loss = 0.008466062, global_step = 2610, label/mean = 0.31787005, loss = 0.008466062, prediction/mean = 0.32102302
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2610: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2610
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2610
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2610 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:loss = 0.007927181, step = 2610
# INFO:tensorflow:Saving checkpoints for 2620 into C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.007916942.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:59:09Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2620
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.24392s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:59:10
# INFO:tensorflow:Saving dict for global step 2620: average_loss = 0.008454996, global_step = 2620, label/mean = 0.31787005, loss = 0.008454996, prediction/mean = 0.32100394
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2620: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2620

# %%
regressor.
# Out:
# <bound method Estimator.eval_dir of <tensorflow_estimator.python.estimator.canned.dnn.DNNRegressorV2 object at 0x0000015DCC92A548>>

# %%
# Evaluate our model on the testing data
loss = []

for iteration in range(5):
    ev = regressor.evaluate(input_fn=lambda: input_fn_new(testing_set, training = True), steps=1)
    loss.append(ev['loss'])
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:54:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.24799s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:54:39
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 0.009285362, global_step = 2000, label/mean = 0.31787005, loss = 0.009285362, prediction/mean = 0.3226376
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:54:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.25348s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:54:40
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 0.009285362, global_step = 2000, label/mean = 0.31787005, loss = 0.009285362, prediction/mean = 0.3226376
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:54:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.25737s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:54:41
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 0.009285362, global_step = 2000, label/mean = 0.31787005, loss = 0.009285362, prediction/mean = 0.3226376
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:54:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.26920s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:54:41
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 0.009285362, global_step = 2000, label/mean = 0.31787005, loss = 0.009285362, prediction/mean = 0.3226376
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-06T16:54:42Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Inference Time : 0.24734s
# INFO:tensorflow:Finished evaluation at 2020-04-06-16:54:42
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 0.009285362, global_step = 2000, label/mean = 0.31787005, loss = 0.009285362, prediction/mean = 0.3226376
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: C:\Users\zgebl\AppData\Local\Temp\tmpubngb3se\model.ckpt-2000

# %%
loss
# Out:
# [0.009285362, 0.009285362, 0.009285362, 0.009285362, 0.009285362]

# %%
# Model performance on testing data
loss_score = ev["loss"]
print("Final Loss on the testing set: {0:f}".format(loss_score))
# Out:
# Final Loss on the testing set: 0.005791

# %% [markdown]
# ### Visualize Model performance

# %%
y = regressor.predict(input_fn=lambda: input_fn_new(testing_set))
predictions = list(itertools.islice(y, testing_set.shape[0]))

pred_values = [d['predictions'] for d in predictions]
pred_list = [d[0] for d in pred_values]
pred_df = pd.DataFrame(pred_list)
# Out:
# WARNING:tensorflow:Input graph does not use tf.data.Dataset or contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zgebl\AppData\Local\Temp\tmpgj4qtt8v\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
predictions = pd.DataFrame(scaler_y.inverse_transform(pred_df), columns=['Predictions'])
reality = pd.DataFrame(scaler_y.inverse_transform(np.array(testing_set.SalePrice).reshape(-1,1)), columns=['Reality'])

# %%
matplotlib.rc('xtick', labelsize=30) 
matplotlib.rc('ytick', labelsize=30) 

fig, ax = plt.subplots(figsize=(50, 40))

plt.style.use('ggplot')
plt.plot(predictions, reality, 'ro')
plt.xlabel('Predictions', fontsize = 30)
plt.ylabel('Reality', fontsize = 30)
plt.title('Predictions x Reality on Housing Prices: DNNREgressor', fontsize = 30)
ax.plot([reality.min(), reality.max()], [reality.min(), reality.max()], 'k--', lw=4)
plt.show()

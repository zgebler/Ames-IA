# %%
import os
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "99"

# %%
# import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, LassoLarsCV
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

import scipy.stats as st


from zipfile import ZipFile
import os

# %matplotlib inline
pd.set_option('display.max_rows', 500)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import itertools

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import matplotlib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Unzip Data
files = os.listdir("data/zipfiles")

# Data can be found here: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
for file in files:
    if file.endswith(".zip"):
        
        with ZipFile('./data/zipfiles/' + file, 'r') as zipObj:
    
       # Check if it is a shape files
            listOfFileNames = zipObj.namelist()
    
            for fileName in listOfFileNames:
            
                zipObj.extract(fileName, './data')

# %%
# Load Training Dataset
train = pd.read_csv("data/train.csv")

# %%
# Load Training Data

# Import and split
train = pd.read_csv('data/train.csv')
train.drop('Id',axis = 1, inplace = True)
# GarageYearBuilt - missing for houses without Garage - Replace with YearBuilt of House
train['GarageYrBlt'].fillna(train['YearBuilt'], inplace = True)
# Lot Frontage - missing at random - Replace with 2/3 the Square root of Lot Area
train['LotFrontage'].fillna(2/3 * np.sqrt(train['LotArea']), inplace = True)
#Masonry Veneer Area - missing at random - replace with mean
train['MasVnrArea'].fillna(np.mean(train['MasVnrArea']), inplace = True)

train_numerical = train.select_dtypes(exclude = ['object'])

# Fill Categorical Missings
train_categoric = train.select_dtypes(include=['object'])
train_categoric.fillna('NONE',inplace = True)

train = train_numerical.merge(train_categoric, left_index = True, right_index = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
t
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# Utilize Isolation Forest Algorithm to remove outliers, based on numeric categories
from sklearn.ensemble import IsolationForest

clf = IsolationForest(max_samples = 100, random_state = 42)
clf.fit(train_numerical)
y_noano = clf.predict(train_numerical)
y_noano = pd.DataFrame(y_noano, columns = ['Top'])
y_noano[y_noano['Top'] == 1].index.values

# Reset index for dataframes
train_numerical = train_numerical.iloc[y_noano[y_noano['Top'] == 1].index.values]
train_numerical.reset_index(drop = True, inplace = True)

train_categoric = train_categoric.iloc[y_noano[y_noano['Top'] == 1].index.values]
train_categoric.reset_index(drop = True, inplace = True)

train = train.iloc[y_noano[y_noano['Top'] == 1].index.values]
train.reset_index(drop = True, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:237: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:247: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)

# %%
train.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageType  \
# 0          2003       196.0         706           0  ...      Attchd
# 1          1976         0.0         978           0  ...      Attchd
# 2          2002       162.0         486           0  ...      Attchd
# 3          1970         0.0         216           0  ...      Detchd
# 4          2000       350.0         655           0  ...      Attchd
#
#    GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  Fence  \
# 0           RFn          TA          TA           Y    NONE   NONE
# 1           RFn          TA          TA           Y    NONE   NONE
# 2           RFn          TA          TA           Y    NONE   NONE
# 3           Unf          TA          TA           Y    NONE   NONE
# 4           RFn          TA          TA           Y    NONE   NONE
#
#    MiscFeature  SaleType  SaleCondition
# 0         NONE        WD         Normal
# 1         NONE        WD         Normal
# 2         NONE        WD         Normal
# 3         NONE        WD        Abnorml
# 4         NONE        WD         Normal
#
# [5 rows x 80 columns]

# %%
# Encode Categorical vars to ordinal ranking based on Sales Price mean
def encode(df, feature):
    ordering = pd.DataFrame()
    ordering['val'] = df[feature].unique()
    ordering.index = ordering.val
    ordering['spmean'] = df[[feature, 'SalePrice']].groupby(feature).mean()['SalePrice']
    ordering = ordering.sort_values('spmean')
    ordering['ordering'] = range(1, ordering.shape[0]+1)
    ordering = ordering['ordering'].to_dict()
    
    for cat, o in ordering.items():
        df.loc[df[feature] == cat, feature+'_E'] = o
    
qual_encoded = []


for q in train_numerical.columns:  
    encode(train, q)
    qual_encoded.append(q+'_E')
print(qual_encoded)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-318-8d0a8e735815> in <module>
#      15
#      16
# ---> 17 for q in train_numerical.columns():
#      18     encode(train, q)
#      19     qual_encoded.append(q+'_E')
#
# TypeError: 'Index' object is not callable

# %%
# Preprocess Data
col_train_num = list(train_numerical.columns)
col_train_num_bis = list(train_numerical.columns)

col_train_cat = list(train_categoric.columns)

col_train_num_bis.remove('SalePrice')

mat_train = np.matrix(train_numerical)
mat_test  = np.matrix(test_numerical)
mat_new = np.matrix(train_numerical.drop('SalePrice',axis = 1))
mat_y = np.array(train.SalePrice)

prepro_y = MinMaxScaler()
prepro_y.fit(mat_y.reshape(1314,1))

prepro = MinMaxScaler()
prepro.fit(mat_train)

prepro_test = MinMaxScaler()
prepro_test.fit(mat_new)

train_num_scale = pd.DataFrame(prepro.transform(mat_train),columns = col_train_num)
test_num_scale  = pd.DataFrame(prepro_test.transform(mat_test),columns = col_train_num_bis)

# %%
train[col_train_num] = pd.DataFrame(prepro.transform(mat_train),columns = col_train_num)
test[col_train_num_bis]  = test_num_scale

# %%
COLUMNS = col_train_num
FEATURES = col_train_num_bis

feature_cols = [tf.compat.v1.convert_to_tensor_or_sparse_tensor(k) for k in FEATURES]

# %%
tf.compat.v1.convert_to_tensor_or_sparse_tensor
# Out:
# [<tf.Tensor: id=151, shape=(), dtype=string, numpy=b'MSSubClass'>,
#  <tf.Tensor: id=152, shape=(), dtype=string, numpy=b'LotFrontage'>,
#  <tf.Tensor: id=153, shape=(), dtype=string, numpy=b'LotArea'>,
#  <tf.Tensor: id=154, shape=(), dtype=string, numpy=b'OverallQual'>,
#  <tf.Tensor: id=155, shape=(), dtype=string, numpy=b'OverallCond'>,
#  <tf.Tensor: id=156, shape=(), dtype=string, numpy=b'YearBuilt'>,
#  <tf.Tensor: id=157, shape=(), dtype=string, numpy=b'YearRemodAdd'>,
#  <tf.Tensor: id=158, shape=(), dtype=string, numpy=b'MasVnrArea'>,
#  <tf.Tensor: id=159, shape=(), dtype=string, numpy=b'BsmtFinSF1'>,
#  <tf.Tensor: id=160, shape=(), dtype=string, numpy=b'BsmtFinSF2'>,
#  <tf.Tensor: id=161, shape=(), dtype=string, numpy=b'BsmtUnfSF'>,
#  <tf.Tensor: id=162, shape=(), dtype=string, numpy=b'TotalBsmtSF'>,
#  <tf.Tensor: id=163, shape=(), dtype=string, numpy=b'1stFlrSF'>,
#  <tf.Tensor: id=164, shape=(), dtype=string, numpy=b'2ndFlrSF'>,
#  <tf.Tensor: id=165, shape=(), dtype=string, numpy=b'LowQualFinSF'>,
#  <tf.Tensor: id=166, shape=(), dtype=string, numpy=b'GrLivArea'>,
#  <tf.Tensor: id=167, shape=(), dtype=string, numpy=b'BsmtFullBath'>,
#  <tf.Tensor: id=168, shape=(), dtype=string, numpy=b'BsmtHalfBath'>,
#  <tf.Tensor: id=169, shape=(), dtype=string, numpy=b'FullBath'>,
#  <tf.Tensor: id=170, shape=(), dtype=string, numpy=b'HalfBath'>,
#  <tf.Tensor: id=171, shape=(), dtype=string, numpy=b'BedroomAbvGr'>,
#  <tf.Tensor: id=172, shape=(), dtype=string, numpy=b'KitchenAbvGr'>,
#  <tf.Tensor: id=173, shape=(), dtype=string, numpy=b'TotRmsAbvGrd'>,
#  <tf.Tensor: id=174, shape=(), dtype=string, numpy=b'Fireplaces'>,
#  <tf.Tensor: id=175, shape=(), dtype=string, numpy=b'GarageYrBlt'>,
#  <tf.Tensor: id=176, shape=(), dtype=string, numpy=b'GarageCars'>,
#  <tf.Tensor: id=177, shape=(), dtype=string, numpy=b'GarageArea'>,
#  <tf.Tensor: id=178, shape=(), dtype=string, numpy=b'WoodDeckSF'>,
#  <tf.Tensor: id=179, shape=(), dtype=string, numpy=b'OpenPorchSF'>,
#  <tf.Tensor: id=180, shape=(), dtype=string, numpy=b'EnclosedPorch'>,
#  <tf.Tensor: id=181, shape=(), dtype=string, numpy=b'3SsnPorch'>,
#  <tf.Tensor: id=182, shape=(), dtype=string, numpy=b'ScreenPorch'>,
#  <tf.Tensor: id=183, shape=(), dtype=string, numpy=b'PoolArea'>,
#  <tf.Tensor: id=184, shape=(), dtype=string, numpy=b'MiscVal'>,
#  <tf.Tensor: id=185, shape=(), dtype=string, numpy=b'MoSold'>,
#  <tf.Tensor: id=186, shape=(), dtype=string, numpy=b'YrSold'>]

# %%
# List of features
COLUMNS = col_train_num
FEATURES = col_train_num_bis
LABEL = "SalePrice"

FEATURES_CAT = col_train_cat

engineered_features = []

for continuous_feature in FEATURES:
    engineered_features.append(
        tf.compat.v1.convert_to_tensor_or_sparse_tensor(continuous_feature))

# %% [markdown]
# ### EDA

# %%
# https://www.kaggle.com/dgawlik/house-prices-eda
quantitative = [var for var in train.columns if train.dtypes[var] != 'object']
quantitative.remove('SalePrice')
quantitative.remove('Id')
qualitative  = [var for var in train.columns if train.dtypes[var] == 'object']

# %%
train[train['GarageYrBlt'].isnull()][['YearBuilt', 'YearRemodAdd']]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL         65.0     6040   Pave   NaN      Reg
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 78      79          90       RL         72.0    10778   Pave   NaN      Reg
# 88      89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 89      90          20       RL         60.0     8070   Pave   NaN      Reg
# 99     100          20       RL         77.0     9320   Pave   NaN      IR1
# 108    109          50       RM         85.0     8500   Pave   NaN      Reg
# 125    126         190       RM         60.0     6780   Pave   NaN      Reg
# 127    128          45       RM         55.0     4388   Pave   NaN      IR1
# 140    141          20       RL         70.0    10500   Pave   NaN      Reg
# 148    149          20       RL         63.0     7500   Pave   NaN      Reg
# 155    156          50       RL         60.0     9600   Pave   NaN      Reg
# 163    164          45       RL         55.0     5500   Pave   NaN      Reg
# 165    166         190       RL         62.0    10106   Pave   NaN      Reg
# 198    199          75       RM         92.0     5520   Pave   NaN      Reg
# 210    211          30       RL         67.0     5604   Pave   NaN      Reg
# 241    242          30       RM         40.0     3880   Pave   NaN      Reg
# 250    251          30       RL         55.0     5350   Pave   NaN      IR1
# 287    288          20       RL          NaN     8125   Pave   NaN      IR1
# 291    292         190       RL         55.0     5687   Pave  Grvl      Reg
# 307    308          50       RM          NaN     7920   Pave  Grvl      IR1
# 375    376          30       RL          NaN    10020   Pave   NaN      IR1
# 386    387          50       RL         58.0     8410   Pave   NaN      Reg
# 393    394          30       RL          NaN     7446   Pave   NaN      Reg
# 431    432          50       RM         60.0     5586   Pave   NaN      IR1
# 434    435         180       RM         21.0     1890   Pave   NaN      Reg
# 441    442          90       RL         92.0    12108   Pave   NaN      Reg
# 464    465          20       RL         60.0     8430   Pave   NaN      Reg
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 520    521         190       RL         60.0    10800   Pave  Grvl      Reg
# 528    529          30       RL         58.0     9098   Pave   NaN      IR1
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 535    536         190       RL         70.0     7000   Pave   NaN      Reg
# 562    563          30       RL         63.0    13907   Pave   NaN      Reg
# 582    583          90       RL         81.0    11841   Grvl   NaN      Reg
# 613    614          20       RL         70.0     8402   Pave   NaN      Reg
# 614    615         180       RM         21.0     1491   Pave   NaN      Reg
# 620    621          30       RL         45.0     8248   Pave  Grvl      Reg
# 635    636         190       RH         60.0    10896   Pave  Pave      Reg
# 636    637          30       RM         51.0     6120   Pave   NaN      Reg
# 638    639          30       RL         67.0     8777   Pave   NaN      Reg
# 649    650         180       RM         21.0     1936   Pave   NaN      Reg
# 705    706         190       RM         70.0     5600   Pave   NaN      Reg
# 710    711          30       RL         56.0     4130   Pave   NaN      IR1
# 738    739          90       RL         60.0    10800   Pave   NaN      Reg
# 750    751          50       RM         55.0     8800   Pave  Grvl      Reg
# 784    785          75       RM         35.0     6300   Pave  Grvl      Reg
# 826    827          45       RM         50.0     6130   Pave   NaN      Reg
# 843    844          90       RL         80.0     8000   Pave   NaN      Reg
# 921    922          90       RL         67.0     8777   Pave   NaN      Reg
# 942    943          90       RL         42.0     7711   Pave   NaN      IR1
# 954    955          90       RL         35.0     9400   Pave   NaN      IR1
# 960    961          20       RL         50.0     7207   Pave   NaN      IR1
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
# 970    971          50       RL         60.0    10800   Pave   NaN      Reg
# 976    977          30       RL         51.0     5900   Pave   NaN      IR1
# 1009  1010          50       RL         60.0     6000   Pave   NaN      Reg
# 1011  1012          90       RL         75.0     9825   Pave   NaN      Reg
# 1030  1031         190       RH          NaN     7082   Pave   NaN      Reg
# 1038  1039         160       RM         21.0     1533   Pave   NaN      Reg
# 1096  1097          70       RM         60.0     6882   Pave   NaN      Reg
# 1123  1124          20       RL         50.0     9405   Pave   NaN      Reg
# 1131  1132          20       RL         63.0    10712   Pave   NaN      Reg
# 1137  1138          50       RL         54.0     6342   Pave   NaN      Reg
# 1143  1144          20       RL          NaN     9000   Pave   NaN      Reg
# 1173  1174          50       RL        138.0    18030   Pave   NaN      IR1
# 1179  1180          20       RL         77.0     8335   Pave   NaN      Reg
# 1218  1219          50       RM         52.0     6240   Pave   NaN      Reg
# 1219  1220         160       RM         21.0     1680   Pave   NaN      Reg
# 1234  1235          70       RH         55.0     8525   Pave   NaN      Reg
# 1257  1258          30       RL         56.0     4060   Pave   NaN      Reg
# 1283  1284          90       RL         94.0     9400   Pave   NaN      Reg
# 1323  1324          30       RL         50.0     5330   Pave   NaN      Reg
# 1325  1326          30       RM         40.0     3636   Pave   NaN      Reg
# 1326  1327          30       RH         70.0     4270   Pave   NaN      Reg
# 1337  1338          30       RM        153.0     4118   Pave  Grvl      IR1
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1407  1408          20       RL          NaN     8780   Pave   NaN      IR1
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 39           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 48           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 78           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 88           Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 89           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 99           Lvl    AllPub  ...        0    NaN    NaN        Shed     400
# 108          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 125          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 127          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 140          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 148          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 155          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 163          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 165          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 198          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 210          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 241          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 250          Lvl    AllPub  ...        0    NaN   GdWo        Shed     450
# 287          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 291          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 307          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 375          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 386          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 393          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 431          Bnk    AllPub  ...        0    NaN  MnPrv         NaN       0
# 434          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 441          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 464          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 495          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 520          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 528          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 533          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 535          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 562          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 582          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 613          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 614          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 620          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 635          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 636          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 638          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 649          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 705          Lvl    AllPub  ...        0    NaN    NaN        Othr    3500
# 710          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 738          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 750          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 784          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 826          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 843          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 921          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 942          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 954          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 960          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 968          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 970          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 976          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1009         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1011         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1030         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1038         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1096         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1123         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1131         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1137         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1143         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1173         Bnk    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1179         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1218         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1219         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1234         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1257         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1283         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 1323         HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 1325         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1326         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1337         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1349         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1407         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1449         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1450         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1453         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 39        6   2008        WD        AdjLand      82000
# 48        6   2009       New        Partial     113000
# 78        4   2010        WD         Normal     136500
# 88       10   2009     ConLD        Abnorml      85000
# 89        8   2007        WD         Normal     123600
# 99        1   2010        WD         Normal     128950
# 108       8   2007        WD         Normal     115000
# 125       6   2006        WD         Normal      84500
# 127       6   2007        WD         Normal      87000
# 140       4   2010     ConLI         Normal     115000
# 148       4   2008        WD         Normal     141000
# 155       4   2008        WD         Normal      79000
# 163       4   2007        WD         Normal     103200
# 165       9   2008        WD         Normal     127500
# 198       7   2009        WD        Abnorml     104000
# 210       4   2008        WD         Normal      98000
# 241       8   2007        WD         Normal     110500
# 250       5   2010        WD         Normal      76500
# 287       6   2006        WD         Normal      88000
# 291       3   2008        WD         Normal     135900
# 307       3   2008        WD         Normal      89500
# 375       3   2009        WD         Normal      61000
# 386       5   2006        WD        AdjLand      81000
# 393       4   2006        WD        Abnorml     100000
# 431       9   2008     ConLD        Abnorml      79900
# 434       6   2008        WD         Normal      81000
# 441       9   2008        WD         Normal     118000
# 464       8   2009        WD         Normal     124000
# 495      11   2009        WD        Abnorml      34900
# 520       8   2008        WD         Normal     106250
# 528       7   2007        WD         Normal      86000
# 533       1   2007        WD         Normal      39300
# 535       1   2008        WD         Normal     107500
# 562       7   2008        WD         Normal     108000
# 582       5   2007        WD         Normal     118500
# 613      12   2007       New        Partial     147000
# 614       5   2010        WD         Normal      75500
# 620       9   2008        WD         Normal      67000
# 635       3   2007        WD        Abnorml     200000
# 636       1   2009     ConLw         Normal      60000
# 638       5   2008        WD         Normal      85000
# 649      12   2007        WD         Normal      84500
# 705       7   2010        WD         Normal      55000
# 710       7   2008        WD         Normal      52000
# 738       3   2009        WD         Alloca     179000
# 750       6   2010        WD         Normal      96500
# 784       6   2008        WD         Normal     128000
# 826       5   2008        WD         Normal     109500
# 843       7   2007        WD         Normal     141000
# 921       9   2008        WD         Normal     145900
# 942       8   2007       Oth        Abnorml     150000
# 954      10   2006        WD        AdjLand     127500
# 960       2   2010        WD         Normal     116500
# 968       5   2009        WD        Abnorml      37900
# 970      12   2006        WD        Abnorml     135000
# 976       8   2006        WD         Normal      85500
# 1009      6   2006        WD         Normal     102000
# 1011      5   2010        WD         Normal     100000
# 1030      7   2006        WD         Normal     160000
# 1038      5   2009        WD         Normal      97000
# 1096      3   2007        WD         Normal     127000
# 1123      6   2009        WD         Normal     118000
# 1131      9   2007       Oth        Abnorml      93500
# 1137      5   2010        WD         Normal      94000
# 1143      7   2008        WD         Normal      80000
# 1173      3   2007        WD         Normal     200500
# 1179      4   2006        WD         Normal      93000
# 1218      7   2006        WD         Normal      80500
# 1219      4   2006        WD        Abnorml      91500
# 1234     11   2008        WD        Abnorml     130000
# 1257      7   2009        WD         Normal      99900
# 1283      4   2010        WD         Normal     139000
# 1323     12   2009        WD         Normal      82500
# 1325      1   2008        WD         Normal      55000
# 1326      5   2007        WD         Normal      79000
# 1337      3   2006        WD         Normal      52500
# 1349     12   2008        WD         Normal     122000
# 1407      3   2009        WD         Normal     112000
# 1449      8   2006        WD        Abnorml      92000
# 1450      9   2009        WD         Normal     136000
# 1453      7   2006        WD        Abnorml      84500
#
# [81 rows x 81 columns]

# %%
missing  = train[quantitative].isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace = True)
missing.plot.bar();

# %%
train[train['GarageYrBlt'] == train['YearBuilt']]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5            Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 4        12   2008        WD         Normal     250000
# 5        10   2009        WD         Normal     143000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1170 rows x 81 columns]

# %%
train[train['MasVnrArea'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 234    235          60       RL          NaN     7851   Pave   NaN      Reg
# 529    530          20       RL          NaN    32668   Pave   NaN      IR1
# 650    651          60       FV         65.0     8125   Pave   NaN      Reg
# 936    937          20       RL         67.0    10083   Pave   NaN      Reg
# 973    974          20       FV         95.0    11639   Pave   NaN      Reg
# 977    978         120       FV         35.0     4274   Pave  Pave      IR1
# 1243  1244          20       RL        107.0    13891   Pave   NaN      Reg
# 1278  1279          60       RL         75.0     9473   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 234          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 529          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 650          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 936          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 973          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 977          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1243         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1278         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 234       5   2010        WD         Normal     216500
# 529       3   2007        WD         Alloca     200624
# 650       5   2008        WD         Normal     205950
# 936       8   2009        WD         Normal     184900
# 973      12   2008       New        Partial     182000
# 977      11   2007       New        Partial     199900
# 1243      9   2006       New        Partial     465000
# 1278      3   2008        WD         Normal     237000
#
# [8 rows x 81 columns]

# %%
train[train['MasVnrArea'].isnull()]['FireplaceQu']
# Out:
# 234      TA
# 529      TA
# 650     NaN
# 936     NaN
# 973     NaN
# 977     NaN
# 1243     Gd
# 1278     Gd
# Name: FireplaceQu, dtype: object

# %%
train.groupby('FireplaceQu').agg({'MasVnrArea':'mean'})
# Out:
#              MasVnrArea
# FireplaceQu
# Ex           294.458333
# Fa           114.787879
# Gd           150.838624
# Po            50.450000
# TA           143.739550

# %%
train[~train['MasVnrType'].isnull()][['FireplaceQu', 'MasVnrArea']]
# Out:
#      FireplaceQu  MasVnrArea
# 0            NaN       196.0
# 1             TA         0.0
# 2             TA       162.0
# 3             Gd         0.0
# 4             TA       350.0
# ...          ...         ...
# 1455          TA         0.0
# 1456          TA       119.0
# 1457          Gd         0.0
# 1458         NaN         0.0
# 1459         NaN         0.0
#
# [1452 rows x 2 columns]

# %%
flag = (train['FireplaceQu'] == 'Gd') | (train['FireplaceQu'] == 'Ex') | (train['FireplaceQu'] == 'TA' )

train[flag][['MasVnrArea', 'MasVnrType']]
# Out:
#       MasVnrArea MasVnrType
# 1            0.0       None
# 2          162.0    BrkFace
# 3            0.0       None
# 4          350.0    BrkFace
# 6          186.0      Stone
# ...          ...        ...
# 1447       438.0    BrkFace
# 1451       194.0      Stone
# 1455         0.0       None
# 1456       119.0      Stone
# 1457         0.0       None
#
# [717 rows x 2 columns]

# %%
train[flag]['MasVnrArea'].hist()

# %%
train[~train['LotFrontage'].isnull()]['Neighborhood'].value_counts(normalize = True)
# Out:
# NAmes      0.154871
# CollgCr    0.104913
# OldTown    0.090758
# Edwards    0.076603
# Somerst    0.064946
# NridgHt    0.063281
# BrkSide    0.042465
# SawyerW    0.041632
# Gilbert    0.040799
# Sawyer     0.039967
# NWAmes     0.037469
# Crawfor    0.034138
# Mitchel    0.029975
# IDOTRR     0.028310
# NoRidge    0.027477
# Timber     0.024979
# SWISU      0.019151
# StoneBr    0.016653
# BrDale     0.013322
# MeadowV    0.012490
# Blmngtn    0.011657
# ClearCr    0.010824
# NPkVill    0.005828
# Veenker    0.005828
# Blueste    0.001665
# Name: Neighborhood, dtype: float64

# %%
train[train['LotFrontage'].isnull()]['Neighborhood'].value_counts(normalize = True)
# Out:
# NAmes      0.150579
# Gilbert    0.115830
# NWAmes     0.108108
# Sawyer     0.100386
# CollgCr    0.092664
# ClearCr    0.057915
# Mitchel    0.050193
# Crawfor    0.038610
# SawyerW    0.034749
# Timber     0.030888
# NoRidge    0.030888
# Edwards    0.030888
# Somerst    0.030888
# BrkSide    0.027027
# StoneBr    0.019305
# OldTown    0.015444
# Veenker    0.015444
# Blmngtn    0.011583
# IDOTRR     0.011583
# MeadowV    0.007722
# NPkVill    0.007722
# SWISU      0.007722
# NridgHt    0.003861
# Name: Neighborhood, dtype: float64

# %%
(2/3 * np.sqrt(train['LotArea'])).hist(bins = 100)

# %%
train['LotFrontage'].hist(bins = 100)

# %%
# Check distribution of target variable
y = train['SalePrice']
plt.figure(1); plt.title('Normal')
sns.distplot(y, kde = False, fit = st.norm)
plt.figure(2); plt.title('Log Normal')
sns.distplot(y, kde = False, fit = st.lognorm)

# %%
# Remove outliers
indexNames = train[train['GrLivArea'] > 4000].index
train.drop(indexNames, inplace = True)

indexNames = train[train['SalePrice'] > 500000].index
train.drop(indexNames, inplace = True)

# %%
# Apply Shapiro-Wilk test for normality of quantitaitve variables, rejecting for p < 0.05
test_normality = lambda x: st.shapiro(x.fillna(0))[1] < 0.05
normal = pd.DataFrame(train[quantitative])
normal = normal.apply(test_normality)
print(not normal.any())
# Out:
# False

# %%
# Check Distribution of quantitative vars

f = pd.melt(train, value_vars=quantitative)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %%
# Check distribution of qualitative
for c in qualitative:
    train[c] = train[c].astype('category')
    if train[c].isnull().any():
        train[c] = train[c].cat.add_categories(['MISSING'])
        train[c] = train[c].fillna('MISSING')

def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
f = pd.melt(train, id_vars=['SalePrice'], value_vars=qualitative)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, height=5)
g = g.map(boxplot, "value", "SalePrice")

# %%
# Cluster by Neighborhood

sns.scatterplot(x = train['SalePrice'], y = (train['GrLivArea']), hue = train['Neighborhood'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
train['Underpriced'] = train['Neighborhood'].apply(lambda x :1 if train['SalePrice'] > np.mean(train['SalePrice']) else 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-e37e66775e77> in <module>
# ----> 1 train['Underpriced'] = train['Neighborhood'].apply(lambda x :1 if train['SalePrice'] > np.mean(train['SalePrice']) else 0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4037             # row-wise access
#    4038             if is_extension_type(self.dtype):
# -> 4039                 mapped = self._values.map(f)
#    4040             else:
#    4041                 values = self.astype(object).values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in map(self, mapper)
#    1249         Index(['first', 'second', nan], dtype='object')
#    1250         """
# -> 1251         new_categories = self.categories.map(mapper)
#    1252         try:
#    1253             return self.from_codes(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in map(self, mapper, na_action)
#    4879         from .multi import MultiIndex
#    4880
# -> 4881         new_values = super()._map_values(mapper, na_action=na_action)
#    4882
#    4883         attributes = self._get_attributes_dict()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1298
#    1299         # mapper is a function
# -> 1300         new_values = map_f(values, mapper)
#    1301
#    1302         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-102-e37e66775e77> in <lambda>(x)
# ----> 1 train['Underpriced'] = train['Neighborhood'].apply(lambda x :1 if train['SalePrice'] > np.mean(train['SalePrice']) else 0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Perform Anova Test to see relationship of qualitative vars on sale price|

def anova(df):
    anv = pd.DataFrame()
    anv['feature'] = qualitative
    pvals = []
    for c in qualitative:
        samples = []
        for cls in df[c].unique():
            s = df[df[c] == cls]['SalePrice'].values
            samples.append(s)
        pval = st.f_oneway(*samples)[1]
        pvals.append(pval)
    anv['pval'] = pvals
    return anv.sort_values('pval')

a = anova(train)
a['disparity'] = np.log(1./a['pval'].values)
sns.barplot(data=a, x='feature', y='disparity')
x=plt.xticks(rotation=90)
# Out:
# C:\Users\zgebl\AppData\Roaming\Python\Python37\site-packages\scipy\stats\stats.py:3347: RuntimeWarning: invalid value encountered in double_scalars
#   msb = ssbn / dfbn

# %%
# Encode Categorical vars to ordinal ranking based on Sales Price mean
def encode(df, feature):
    ordering = pd.DataFrame()
    ordering['val'] = df[feature].unique()
    ordering.index = ordering.val
    ordering['spmean'] = df[[feature, 'SalePrice']].groupby(feature).mean()['SalePrice']
    ordering = ordering.sort_values('spmean')
    ordering['ordering'] = range(1, ordering.shape[0]+1)
    ordering = ordering['ordering'].to_dict()
    
    for cat, o in ordering.items():
        df.loc[df[feature] == cat, feature+'_E'] = o
    
qual_encoded = []
for q in qualitative:  
    encode(train, q)
    qual_encoded.append(q+'_E')
print(qual_encoded)
# Out:
# ['MSZoning_E', 'Street_E', 'Alley_E', 'LotShape_E', 'LandContour_E', 'Utilities_E', 'LotConfig_E', 'LandSlope_E', 'Neighborhood_E', 'Condition1_E', 'Condition2_E', 'BldgType_E', 'HouseStyle_E', 'RoofStyle_E', 'RoofMatl_E', 'Exterior1st_E', 'Exterior2nd_E', 'MasVnrType_E', 'ExterQual_E', 'ExterCond_E', 'Foundation_E', 'BsmtQual_E', 'BsmtCond_E', 'BsmtExposure_E', 'BsmtFinType1_E', 'BsmtFinType2_E', 'Heating_E', 'HeatingQC_E', 'CentralAir_E', 'Electrical_E', 'KitchenQual_E', 'Functional_E', 'FireplaceQu_E', 'GarageType_E', 'GarageFinish_E', 'GarageQual_E', 'GarageCond_E', 'PavedDrive_E', 'PoolQC_E', 'Fence_E', 'MiscFeature_E', 'SaleType_E', 'SaleCondition_E']

# %%
train['MSZoning_E']
# Out:
# 0       4.0
# 1       4.0
# 2       4.0
# 3       4.0
# 4       4.0
#        ...
# 1309    5.0
# 1310    4.0
# 1311    4.0
# 1312    4.0
# 1313    4.0
# Name: MSZoning_E, Length: 1314, dtype: float64

# %%
def spearman(df, features):
    spr = pd.DataFrame()
    spr['feature'] = features
    spr['spearman'] = [df[f].corr(df['SalePrice'], 'spearman') for f in features]
    spr = spr.sort_values('spearman')
    plt.figure(figsize=(6, 0.25*len(features)))
    sns.barplot(data=spr, y='feature', x='spearman', orient='h')
    
features = quantitative + qual_encoded
spearman(train, features)

# %%
# Correlations


plt.figure(1)
corr = train[quantitative+['SalePrice']].corr()
sns.heatmap(corr)
plt.figure(2)
corr = train[qual_encoded+['SalePrice']].corr()
sns.heatmap(corr)

# %%
# Feature selection - take top 10 features

features = ['OverallQual', 'Neighborhood_E', 'GrLivArea', 'GarageCars',
            'ExterQual_E', 'BsmtQual_E', 'KitchenQual_E',
           'YearBuilt', 'GarageArea', 'FullBath', 'GarageFinish_E', 'TotalBsmtSF', 'MoSold']


quantitative = ['OverallQual', 'GrLivArea', 'GarageCars', 'YearBuilt', 'GarageArea', 'FullBath',  'TotalBsmtSF', 'MoSold']
qual_encoded       = ['ExterQual_E', 'BsmtQual_E', 'KitchenQual_E','Neighborhood_E','GarageFinish_E']

# %%
# Check relationship between target and features

def pairplot(x, y, **kwargs):
    ax = plt.gca()
    ts = pd.DataFrame({'time': x, 'val': y})
    ts = ts.groupby('time').mean()
    ts.plot(ax=ax)
    plt.xticks(rotation=90)
    
f = pd.melt(train, id_vars=['SalePrice'], value_vars=quantitative+qual_encoded)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(pairplot, "value", "SalePrice")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Modeling


def error(actual, predicted):
    actual = np.log(actual)
    predicted = np.log(predicted)
    return np.sqrt(np.sum(np.square(actual-predicted))/len(actual))


def log_transform(feature):
    train[feature] = np.log1p(train[feature].values)

def quadratic(feature):
    train[feature+'2'] = train[feature]**2
    

log_transform('GrLivArea')
log_transform('GarageArea')

quadratic('OverallQual')
quadratic('YearBuilt')
quadratic('TotalBsmtSF')
quadratic('Neighborhood_E')
quadratic('GrLivArea')

qdr = ['OverallQual2', 'YearBuilt2', 'TotalBsmtSF2', 'Neighborhood_E2', 'GrLivArea2']

features = quantitative + qual_encoded + qdr

# %%
y = train['SalePrice']

X = train[features]


#dummies = pd.get_dummies(train['Neighborhood'])

#X = pd.concat([X,dummies], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_train.shape
# Out:
# (919, 18)

# %%
# Fit Lasso Regression
lasso = LassoLarsCV(max_iter= 10000)
lasso.fit(X_train, np.log(y_train))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# LassoLarsCV(copy_X=True, cv='warn', eps=2.220446049250313e-16,
#             fit_intercept=True, max_iter=10000, max_n_alphas=1000, n_jobs=None,
#             normalize=True, positive=False, precompute='auto', verbose=False)

# %%
y_pred = np.exp(lasso.predict(X_test))

# %%
error(y_test, y_pred)
# Out:
# 0.13434279952339784

# %%
lasso.score(X_train, y_train)
# Out:
# -7.398126166920715

# %%
lasso.score(X_test, y_test)
# Out:
# -7.026534431497156

# %%
# Fit Linear Regression
